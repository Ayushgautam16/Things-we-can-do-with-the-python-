# %%
import numpy as np

# %%
# Array operations

# %%
a1 = np.array([1,2,3,4,5])
a2 = np.array([6,7,8,9,0])

# %%
arr2  = a1+a2
arr2
# Out:
# array([ 7,  9, 11, 13,  5])

# %%
a1+a2
# Out:
# array([ 7,  9, 11, 13,  5])

# %%
a1-a2
# Out:
# array([-5, -5, -5, -5,  5])

# %%
a2/a1
# Out:
# array([6.        , 3.5       , 2.66666667, 2.25      , 0.        ])

# %%
a2//a1
# Out:
# array([6, 3, 2, 2, 0])

# %%
a1*a2
# Out:
# array([ 6, 14, 24, 36,  0])

# %%
# Broadcastinga

# %%
m = [10,20,30,40]
arr = np.array(m)

# %%
arr = 10

# %%
# deep and shallow copy
